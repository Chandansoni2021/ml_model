# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.8,random_state=21)

# %%
data[0].shape
# Out:
# (200, 2)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=4)

# %%
km.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
km.cluster_centers_
# Out:
# array([[-9.01744404, -3.74576527],
#        [ 4.03192913, -9.54741549],
#        [-3.90357975,  3.72905281],
#        [-5.53987856, -9.44770702]])

# %%
km.labels_
# Out:
# array([3, 3, 2, 1, 0, 1, 3, 3, 2, 2, 0, 0, 3, 0, 2, 2, 3, 0, 1, 0, 2, 3,
#        2, 0, 0, 3, 2, 3, 1, 3, 2, 2, 3, 3, 3, 1, 3, 3, 2, 2, 1, 0, 2, 3,
#        1, 1, 1, 0, 3, 2, 0, 0, 3, 2, 2, 2, 2, 3, 3, 0, 2, 2, 1, 1, 1, 1,
#        0, 3, 1, 2, 1, 0, 2, 0, 2, 0, 2, 2, 0, 1, 0, 3, 3, 2, 0, 1, 3, 3,
#        3, 1, 3, 0, 3, 0, 2, 3, 1, 1, 1, 0, 0, 1, 0, 2, 1, 2, 1, 2, 3, 0,
#        0, 1, 0, 1, 1, 3, 0, 0, 2, 3, 0, 3, 1, 1, 1, 3, 1, 0, 3, 0, 0, 3,
#        3, 0, 0, 1, 1, 1, 2, 3, 0, 1, 0, 3, 2, 0, 2, 3, 1, 1, 2, 0, 0, 3,
#        3, 1, 2, 1, 0, 1, 0, 3, 3, 0, 0, 0, 1, 2, 2, 1, 1, 2, 1, 2, 3, 1,
#        2, 2, 2, 2, 2, 3, 1, 2, 3, 0, 3, 0, 3, 1, 0, 1, 2, 1, 1, 2, 2, 0,
#        3, 3])

# %%
fig,(ax1,ax2)=plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title('K means')
ax1.scatter(data[0][:,0],data[0][:,1],c=km.labels_,cmap='rainbow')
ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
